# %%
import pandas as pd
from scipy import stats
import numpy as np
import seaborn as sns

d=pd.read_csv("E:/New folder (3)/immo_data.csv")
df = pd.DataFrame(data=d)
df
sns.boxplot(x=df['picturecount'])

# %%
Q1 =df.quantile(0.25)
Q3 =df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)

# %%
z = np.abs(stats.zscore(df))

# %%
df_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
